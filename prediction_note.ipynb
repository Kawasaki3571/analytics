# %%
# !ls ./datasets
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
# Out:
# atp_matches_2013.csv atp_matches_2016.csv atp_matches_2019.csv
# atp_matches_2014.csv atp_matches_2017.csv atp_matches_2020.csv
# atp_matches_2015.csv atp_matches_2018.csv

# %%
data_2013 = pd.read_csv("./datasets/atp_matches_2013.csv")
data_2014 = pd.read_csv("./datasets/atp_matches_2014.csv")
data_2015 = pd.read_csv("./datasets/atp_matches_2015.csv")
data_2016 = pd.read_csv("./datasets/atp_matches_2016.csv")
data_2017 = pd.read_csv("./datasets/atp_matches_2017.csv")
data_2018 = pd.read_csv("./datasets/atp_matches_2018.csv")
data_2019 = pd.read_csv("./datasets/atp_matches_2019.csv")
data_2020 = pd.read_csv("./datasets/atp_matches_2020.csv")
data_2013b = data_2013
data_2014b = data_2014
data_2015b = data_2015
data_2016b = data_2016
data_2017b = data_2017
data_2018b = data_2018
data_2019b = data_2019
data_2020b = data_2020
data_array = [data_2013, data_2014, data_2015, data_2016, data_2017, data_2018, data_2019, data_2020]
data_all = pd.concat(data_array)

# %%
print(data_2020.isnull().any(), data_2020.columns)
# Out:
# tourney_id            False
# tourney_name          False
# surface               False
# draw_size             False
# tourney_level         False
# tourney_date          False
# match_num             False
# winner_id             False
# winner_seed            True
# winner_entry           True
# winner_name           False
# winner_hand           False
# winner_ht              True
# winner_ioc            False
# winner_age            False
# loser_id              False
# loser_seed             True
# loser_entry            True
# loser_name            False
# loser_hand            False
# loser_ht               True
# loser_ioc             False
# loser_age             False
# score                 False
# best_of               False
# round                 False
# minutes               False
# w_ace                  True
# w_df                   True
# w_svpt                 True
# w_1stIn                True
# w_1stWon               True
# w_2ndWon               True
# w_SvGms                True
# w_bpSaved              True
# w_bpFaced              True
# l_ace                  True
# l_df                   True
# l_svpt                 True
# l_1stIn                True
# l_1stWon               True
# l_2ndWon               True
# l_SvGms                True
# l_bpSaved              True
# l_bpFaced              True
# winner_rank            True
# winner_rank_points     True
# loser_rank             True
# loser_rank_points      True
# dtype: bool Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
needless_columns = ['w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
       'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
       'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
       'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points' ]
data_all = data_all.drop(columns = needless_columns, axis=1)

# %%
#文献からパクる
data_all.columns
win_count = data_all.groupby("winner_name")["winner_id"].count().reset_index()
win_count.columns=["name","win_count"]
lose_count=data_all.groupby("loser_name")["loser_id"].count().reset_index()
lose_count.columns=["name","lose_count"]
counts=pd.merge(win_count,lose_count,on="name",how="outer")
counts=counts.fillna(0)
counts["sum"] = counts["win_count"] + counts["lose_count"]
counts["win_rate"] = counts["win_count"] / counts["sum"]
counts.head(20)
# Out:
#                            name  win_count  lose_count    sum  win_rate
# 0               Abdullah Maqdas        4.0         4.0    8.0  0.500000
# 1                 Adam Pavlasek        6.0         9.0   15.0  0.400000
# 2          Aditya Hari Sasongko        2.0         4.0    6.0  0.333333
# 3              Adrian Mannarino      168.0       186.0  354.0  0.474576
# 4      Adrian Menendez Maceiras        6.0        17.0   23.0  0.260870
# 5                  Adrian Ungur       11.0        23.0   34.0  0.323529
# 6          Aisam Ul Haq Qureshi        7.0         6.0   13.0  0.538462
# 7                     Ajeet Rai        1.0         1.0    2.0  0.500000
# 8               Akira Santillan        2.0         7.0    9.0  0.222222
# 9               Albano Olivetti        3.0         7.0   10.0  0.300000
# 10              Albert Montanes       46.0        52.0   98.0  0.469388
# 11                 Albert Ramos      175.0       186.0  361.0  0.484765
# 12                  Alberto Lim        3.0         4.0    7.0  0.428571
# 13                 Aldin Setkic        2.0         3.0    5.0  0.400000
# 14  Alejandro Davidovich Fokina        5.0        11.0   16.0  0.312500
# 15              Alejandro Falla       34.0        54.0   88.0  0.386364
# 16         Alejandro Gomez Gb42        1.0         1.0    2.0  0.500000
# 17           Alejandro Gonzalez       18.0        42.0   60.0  0.300000
# 18             Alejandro Tabilo        2.0         2.0    4.0  0.500000
# 19         Aleksandr Nedovyesov        6.0        25.0   31.0  0.193548

# %%
counts2 = counts[counts["sum"] >= 20]
# counts2 = counts2.dorp(columns ="index", axis=1)
counts2 = counts2.sort_values(by="sum", ascending=False).reset_index()
counts2 = counts2.drop(columns ="index", axis=1)
player_number = 30
players = counts2[0 : player_number]["name"].unique()
print(players)
# Out:
# ['Novak Djokovic' 'Rafael Nadal' 'Roberto Bautista Agut' 'Roger Federer'
#  'Fabio Fognini' 'Dominic Thiem' 'Kei Nishikori' 'Marin Cilic'
#  'John Isner' 'Grigor Dimitrov' 'David Goffin' 'Stan Wawrinka'
#  'Gilles Simon' 'Milos Raonic' 'Tomas Berdych' 'Joao Sousa'
#  'Richard Gasquet' 'Benoit Paire' 'David Ferrer' 'Philipp Kohlschreiber'
#  'Gael Monfils' 'Fernando Verdasco' 'Andy Murray' 'Kevin Anderson'
#  'Albert Ramos' 'Feliciano Lopez' 'Adrian Mannarino' 'Jeremy Chardy'
#  'Andreas Seppi' 'Sam Querrey']

# %%
dic_target_player = {}
 
for player in players:
    if player not in dic_target_player:
        dic_target_player[player] = len(dic_target_player)+1
        
dic_target_player
# Out:
# {'Novak Djokovic': 1,
#  'Rafael Nadal': 2,
#  'Roberto Bautista Agut': 3,
#  'Roger Federer': 4,
#  'Fabio Fognini': 5,
#  'Dominic Thiem': 6,
#  'Kei Nishikori': 7,
#  'Marin Cilic': 8,
#  'John Isner': 9,
#  'Grigor Dimitrov': 10,
#  'David Goffin': 11,
#  'Stan Wawrinka': 12,
#  'Gilles Simon': 13,
#  'Milos Raonic': 14,
#  'Tomas Berdych': 15,
#  'Joao Sousa': 16,
#  'Richard Gasquet': 17,
#  'Benoit Paire': 18,
#  'David Ferrer': 19,
#  'Philipp Kohlschreiber': 20,
#  'Gael Monfils': 21,
#  'Fernando Verdasco': 22,
#  'Andy Murray': 23,
#  'Kevin Anderson': 24,
#  'Albert Ramos': 25,
#  'Feliciano Lopez': 26,
#  'Adrian Mannarino': 27,
#  'Jeremy Chardy': 28,
#  'Andreas Seppi': 29,
#  'Sam Querrey': 30}

# %%
LW = []
 
for player_a in players:
    for player_b in players:
        
        df_tmp = data_all[
            (data_all['winner_name'] == player_a) &
            (data_all['loser_name'] == player_b)
        ]
        for _ in range(len(df_tmp)):
            LW.append([dic_target_player[player_b], dic_target_player[player_a]])
            
        df_tmp = data_all[
            (data_all['winner_name'] == player_b) &
            (data_all['loser_name'] == player_a)
        ]
        
        for _ in range(len(df_tmp)):
            LW.append([dic_target_player[player_a], dic_target_player[player_b]])
LW = np.array(LW, dtype=np.int32)
print(LW)
# Out:
# [[ 2  1]
#  [ 2  1]
#  [ 2  1]
#  ...
#  [30 28]
#  [30 29]
#  [30 29]]

# %%
print(len(LW))
# Out:
# 4266

# %%
import pystan
print("aaa")

stan_data = {'N':  len(dic_target_player), 'G':len(LW),  'LW': LW}
fit1 = pystan.stan(file='./mcmc.stan',data=stan_data, iter=1000, chains=4, thin=1)
la1 = fit1.extract()
fit1
# Out:
# WARNING:pystan:DeprecationWarning: pystan.stan was deprecated in version 2.17 and will be removed in version 3.0. Compile and use a Stan program in separate steps.
# aaa
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_63f3806daf2ed78c943b466eeb17cf5a NOW.
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# WARNING:pystan:Chain 1: E-BFMI = 0.138
# WARNING:pystan:Chain 2: E-BFMI = 0.106
# WARNING:pystan:Chain 3: E-BFMI = 0.189
# WARNING:pystan:Chain 4: E-BFMI = 0.124
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model
# WARNING:pystan:Truncated summary with the 'fit.__repr__' method. For the full summary use 'print(fit)'
# Warning: Shown data is truncated to 100 parameters
# For the full summary use 'print(fit)'
#
# Inference for Stan model: anon_model_63f3806daf2ed78c943b466eeb17cf5a.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#                     mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# performance[1,1]     2.1    0.02   0.69   0.69   1.67   2.12   2.54   3.47   1296    1.0
# performance[2,1]    2.08    0.02    0.7   0.69   1.64   2.09   2.54   3.48   1277    1.0
# performance[3,1]    2.11    0.02    0.7   0.69   1.69   2.12   2.56   3.44   1649    1.0
# performance[4,1]     2.1    0.02   0.73   0.46   1.65    2.1   2.56   3.47   1189    1.0
# performance[5,1]    2.09    0.02   0.69   0.57   1.68   2.11   2.53    3.4   1277    1.0
# performance[6,1]    2.11    0.02    0.7   0.72   1.66   2.13   2.55    3.5   1210    1.0
# performance[7,1]    2.08    0.02   0.68   0.64   1.69   2.09    2.5   3.46   1670    1.0
# performance[8,1]    2.09    0.02   0.68   0.71   1.67   2.09   2.52   3.45   1695    1.0
# performance[9,1]    2.13    0.02    0.7   0.69    1.7   2.12   2.56   3.53   1429    1.0
# performance[10,1]   2.11    0.02   0.72   0.63   1.67   2.13   2.57   3.51   1466    1.0
# performance[11,1]    2.1    0.02   0.68   0.65   1.67    2.1   2.55    3.4   1673    1.0
# performance[12,1]   2.09    0.02   0.71   0.58   1.68   2.12   2.54   3.44   1960    1.0
# performance[13,1]   2.09    0.02   0.72   0.58   1.67   2.12   2.55    3.5   1094    1.0
# performance[14,1]   2.11    0.02   0.68   0.72   1.68   2.11   2.57    3.4   1703    1.0
# performance[15,1]   2.11    0.02   0.69   0.68   1.69   2.14   2.57    3.4   1465    1.0
# performance[16,1]   1.95    0.03   0.81   0.15   1.44   2.01   2.49    3.4    778    1.0
# performance[17,1]   1.97    0.03   0.81   0.29   1.47   1.99   2.51   3.45    923   1.01
# performance[18,1]   1.94    0.04    0.8   0.35    1.4   1.98   2.48   3.43    443   1.01
# performance[19,1]   1.95    0.03   0.79   0.25    1.5   1.96   2.44   3.42    661   1.01
# performance[20,1]   1.98    0.03   0.79   0.28   1.51   2.04   2.51   3.39    757   1.01
# performance[21,1]   1.95    0.03   0.82   0.25   1.44   1.97    2.5    3.5    641   1.01
# performance[22,1]   1.94    0.03   0.79   0.31   1.43   1.98   2.48   3.42    627    1.0
# performance[23,1]   0.51    0.03   1.18  -1.89  -0.23   0.57   1.29   2.72   2128    1.0
# performance[24,1]   0.53    0.02   1.16  -1.89   -0.2   0.58   1.35   2.69   2563    1.0
# performance[25,1]   0.53    0.02   1.11  -1.73  -0.17   0.58   1.27   2.57   2291    1.0
# performance[26,1]    0.5    0.02   1.15  -1.92  -0.23   0.58   1.33    2.6   2383    1.0
# performance[27,1]   0.53    0.03   1.16  -1.97  -0.19   0.57   1.31    2.6   1891    1.0
# performance[28,1]   0.55    0.03   1.18  -2.07  -0.19   0.62   1.38   2.65   1766    1.0
# performance[29,1]   0.53    0.02   1.14  -1.85  -0.17   0.56   1.29   2.61   2353    1.0
# performance[30,1]   0.49    0.03   1.12  -1.95  -0.23   0.57   1.29   2.45   1483    1.0
# performance[31,1]   1.59    0.05    0.9  -0.23   1.02   1.62   2.18   3.34    318   1.01
# performance[32,1]    1.6    0.05   0.92  -0.24    1.0   1.64   2.21   3.32    303   1.01
# performance[33,1]   1.57    0.05    0.9  -0.28   0.99    1.6   2.14   3.27    352    1.0
# performance[34,1]   2.01    0.02    0.9   0.17   1.43   2.03   2.61   3.75   1660    1.0
# performance[35,1]   2.04    0.02   0.87   0.19   1.48   2.08    2.6   3.73   2102    1.0
# performance[36,1]   2.04    0.02   0.88   0.33   1.46   2.07   2.63   3.74   1680    1.0
# performance[37,1]   2.02    0.02   0.88   0.23   1.47   2.03   2.61   3.66   1565    1.0
# performance[38,1]   2.02    0.02   0.86   0.27   1.44   2.04   2.61   3.67   1483    1.0
# performance[39,1]   2.06    0.02    0.9   0.13    1.5   2.08   2.68   3.76   1350    1.0
# performance[40,1]   2.04    0.02   0.89   0.09   1.48   2.08   2.66   3.77   2015    1.0
# performance[41,1]   2.05    0.02   0.85   0.35   1.51   2.05    2.6   3.78   1433    1.0
# performance[42,1]   2.03    0.02   0.84   0.29   1.51   2.04   2.58   3.66   2057    1.0
# performance[43,1]   2.02    0.02    0.9   0.21   1.46   2.04   2.61   3.74   2736    1.0
# performance[44,1]   2.04    0.02   0.86   0.34   1.51   2.06   2.61   3.68   2253    1.0
# performance[45,1]   2.01    0.02   0.87   0.21   1.49   2.03    2.6   3.68   1855    1.0
# performance[46,1]   2.03    0.02   0.87   0.27   1.46   2.08   2.61   3.65   1741    1.0
# performance[47,1]   2.05    0.02   0.87   0.34   1.48   2.05   2.64   3.75   1625    1.0
# performance[48,1]   2.05    0.02   0.87   0.27   1.49   2.08   2.62   3.76   1713    1.0
# performance[49,1]   2.13    0.02   0.86   0.25    1.6   2.18   2.68   3.74   1368    1.0
# performance[50,1]   2.11    0.03   0.84   0.41   1.59   2.13   2.66   3.65    849    1.0
# performance[51,1]   2.12    0.03   0.87   0.32   1.57   2.14    2.7   3.82   1088    1.0
# performance[52,1]   2.12    0.02   0.86   0.41   1.54   2.14   2.71   3.75   1462    1.0
# performance[53,1]    2.1    0.03   0.89   0.26   1.54   2.13   2.74   3.84   1194    1.0
# performance[54,1]    2.1    0.02   0.86   0.39   1.55   2.12   2.66   3.78   1455    1.0
# performance[55,1]   2.12    0.02   0.82   0.46   1.59   2.13   2.67   3.65   1520    1.0
# performance[56,1]   0.68    0.03   1.12  -1.66  -0.01   0.71   1.47   2.69   1914    1.0
# performance[57,1]   0.68    0.03   1.14  -1.64  -0.03   0.74   1.48   2.73   1901    1.0
# performance[58,1]   0.62    0.02   1.13  -1.71   -0.1   0.68   1.39   2.64   2153    1.0
# performance[59,1]   0.66    0.03   1.08  -1.72  -0.03    0.7    1.4   2.65   1756    1.0
# performance[60,1]   0.67    0.02    1.1  -1.56  -0.03   0.69   1.42   2.73   2035    1.0
# performance[61,1]   0.83    0.03   1.49  -2.44  -0.09   0.97   1.85   3.39   2600    1.0
# performance[62,1]   0.85    0.03   1.46  -2.27  -0.08   0.97   1.87    3.4   1761    1.0
# performance[63,1]   0.86    0.03   1.48  -2.35  -0.07   0.98   1.87    3.5   1833    1.0
# performance[64,1]   0.87    0.03   1.41  -2.02  -0.05   0.92   1.83    3.5   1756    1.0
# performance[65,1]   0.85    0.03   1.44  -2.26  -0.06   1.02   1.83   3.41   2066    1.0
# performance[66,1]   0.87    0.03   1.45  -2.31  -0.02   0.97   1.91   3.44   1828    1.0
# performance[67,1]   0.83    0.03   1.48  -2.43   -0.1   0.94   1.82   3.48   2205    1.0
# performance[68,1]   2.14    0.03   1.01-7.2e-3   1.52   2.19   2.81   4.04   1387    1.0
# performance[69,1]   2.13    0.02   1.01   0.08   1.47   2.16   2.78    4.0   1820    1.0
# performance[70,1]   2.14    0.02   0.97   0.18   1.52   2.15   2.78    4.1   1883    1.0
# performance[71,1]   2.14    0.02   0.97   0.25    1.5   2.13   2.78   4.07   1546    1.0
# performance[72,1]   1.36    0.02    0.9   -0.3   0.74   1.35   1.94   3.18   1799    1.0
# performance[73,1]   1.33    0.02   0.87  -0.48   0.79   1.34    1.9   2.92   2687    1.0
# performance[74,1]   1.33    0.02   0.86  -0.43   0.79   1.35   1.89   3.03   2292    1.0
# performance[75,1]   1.31    0.02   0.87  -0.42   0.73   1.31   1.88   2.99   2343    1.0
# performance[76,1]   1.32    0.02   0.87  -0.58   0.78   1.35   1.89   3.01   2073    1.0
# performance[77,1]   1.34    0.02   0.88  -0.42   0.77   1.36   1.93   3.04   1741    1.0
# performance[78,1]   1.32    0.02   0.86  -0.43   0.79   1.33   1.91   2.99   2430    1.0
# performance[79,1]   1.33    0.02    0.9  -0.38   0.73   1.32   1.93   3.07   2021    1.0
# performance[80,1]   1.32    0.02   0.88  -0.48   0.75   1.34    1.9   3.02   2444    1.0
# performance[81,1]   1.32    0.02   0.88  -0.48   0.75   1.35   1.92   2.99   1822    1.0
# performance[82,1]   1.34    0.02   0.87  -0.41   0.78   1.35   1.92   2.99   2122    1.0
# performance[83,1]   1.33    0.02   0.86  -0.39   0.79   1.32   1.88   3.04   2100    1.0
# performance[84,1]   1.34    0.02   0.89  -0.45   0.75   1.36   1.93   3.06   2757    1.0
# performance[85,1]   1.31    0.02   0.83  -0.39   0.77   1.32   1.87   2.91   2156    1.0
# performance[86,1]   1.33    0.02   0.87  -0.36   0.74   1.34   1.93    3.0   2256    1.0
# performance[87,1]   1.32    0.02    0.9  -0.53   0.75   1.38   1.92   2.99   2251    1.0
# performance[88,1]   1.31    0.02   0.88  -0.48   0.75   1.34   1.87   3.05   2590    1.0
# performance[89,1]   1.71    0.03   0.86  -0.11   1.16   1.72   2.29   3.34    870    1.0
# performance[90,1]   0.95    0.02   1.07  -1.27   0.27    1.0    1.7   2.92   2626    1.0
# performance[91,1]   0.96    0.02   1.09  -1.41   0.24   1.03    1.7   2.88   2584    1.0
# performance[92,1]   0.95    0.02    1.1  -1.36   0.25   1.01    1.7    3.0   2111    1.0
# performance[93,1]   0.98    0.02   1.08  -1.48   0.36   1.06    1.7    2.9   2323    1.0
# performance[94,1]   0.97    0.02   1.04  -1.22   0.31   0.96   1.68   2.94   2057    1.0
# performance[95,1]   0.98    0.02   1.06  -1.23   0.27   1.01   1.72   2.92   2320    1.0
# performance[96,1]   0.93    0.02   1.02  -1.17   0.26   0.99   1.65   2.78   2572    1.0
# performance[97,1]   0.97    0.02   1.04   -1.2   0.29   1.02   1.72   2.86   2385    1.0
# performance[98,1]   0.95    0.02   1.05  -1.28    0.3   0.99   1.68    2.9   2611    1.0
# performance[99,1]   0.96    0.02   1.02   -1.2   0.33   0.99   1.67   2.78   2371    1.0
# lp__               -4224   47.28 266.78  -4726  -4411  -4242  -4039  -3676     32   1.14
#
# Samples were drawn using NUTS at Wed Mar 11 04:03:15 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
! gcc --version
# Out:
# gcc (Homebrew GCC 8.4.0) 8.4.0
# Copyright (C) 2018 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
